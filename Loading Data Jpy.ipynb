# %%
# pip install pandas #if you dont have the package

# %%
# load dataset

import pandas as pd 

# make sure you have your datafile in the same folder as your code for easy access

myData = pd.read_csv('titanic.csv')

# if you hava a text file (.txt) you can use the read_csv function
# # it uses spaces as delimiters 
# # but we can specify what delimiters are 
# # newData = pd.read_csv('myexampletabe.txt', delimiter = '\t')
# for excel we use xlsx

# %%
myData
# Out:
#       pclass  survived                                     name     sex  age  \
# 0          3         1  Dean, Miss. Elizabeth Gladys "Millvina"  female  0.0
# 1          3         0  Danbom, Master. Gilbert Sigvard Emanuel    male  0.0
# 2          3         1          Thomas, Master. Assad Alexander    male  0.0
# 3          2         1                Hamalainen, Master. Viljo    male  1.0
# 4          3         1                   Baclini, Miss. Eugenie  female  1.0
# ...      ...       ...                                      ...     ...  ...
# 1304       3         0        Williams, Mr. Howard Hugh "Harry"    male  NaN
# 1305       3         0                   Wiseman, Mr. Phillippe    male  NaN
# 1306       3         0                        Yousif, Mr. Wazli    male  NaN
# 1307       3         0                    Yousseff, Mr. Gerious    male  NaN
# 1308       3         0                    Zabour, Miss. Thamine  female  NaN
#
# ...
